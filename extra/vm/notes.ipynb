# %% [markdown]
# 1. Follow the instructions at https://docs.docker.com/installation/mac/ through **Basic Boot2Docker exercises**

# %% [markdown]
# ~~`brew install boot2docker`~~
# 1. Download `Boot2Docker-1.7.1.pkg` from https://github.com/boot2docker/osx-installer/releases/latest
# 2. Run `/Applications/boot2docker.app`

# %%
eval "$(boot2docker shellinit)"
# Out:
# Writing /Users/alessandro/.boot2docker/certs/boot2docker-vm/ca.pem
# Writing /Users/alessandro/.boot2docker/certs/boot2docker-vm/cert.pem
# Writing /Users/alessandro/.boot2docker/certs/boot2docker-vm/key.pem

# %%
docker run hello-world
# Out:
# Unable to find image 'hello-world:latest' locally
# latest: Pulling from hello-world
#
# a8219747be10: Pulling fs layer
# hello-world:latest: The image you are pulling has been verified. Important: image verification is a tech preview feature and should not be relied on to provide security.
# Digest: sha256:aa03e5d0d5553b4c3473e89c8619cf79df368babd18681cf5daeb82aab55838d
# Status: Downloaded newer image for hello-world:latest
# Hello from Docker.
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (Assuming it was not already locally available.)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# For more examples and ideas, visit:
#  http://docs.docker.com/userguide/

# %% [markdown]
# ### `DOCKER_HOST` is a VM layer between the host OS and the docker images:
# ![Docker Host](https://docs.docker.com/installation/images/mac_docker_host.svg)

# %%
boot2docker status
# Out:
# running

# %% [markdown]
# This tells us that `DOCKER_HOST` is running, though right now, there are no daemons running inside of it yet.

# %%
docker version
# Out:
# Client version: 1.7.1
# Client API version: 1.19
# Go version (client): go1.4.2
# Git commit (client): 786b29d
# OS/Arch (client): darwin/amd64
# Server version: 1.7.1
# Server API version: 1.19
# Go version (server): go1.4.2
# Git commit (server): 786b29d
# OS/Arch (server): linux/amd64

# %%
docker run -d --name web nginx
# Out:
# 5ace7dc12696625d8e2eed9635a71bd8fd325625f3fd86344ff07fba2bfc3288

# %%
docker ps
# Out:
# CONTAINER ID        IMAGE               COMMAND                CREATED             STATUS                  PORTS               NAMES
# 5ace7dc12696        nginx               "nginx -g 'daemon of   1 seconds ago       Up Less than a second   80/tcp, 443/tcp     web

# %%
docker port web

# %%
boot2docker ip
# Out:
# 192.168.59.103

# %%
docker inspect web
# Out:
# [
# {
#     "Id": "5ace7dc12696625d8e2eed9635a71bd8fd325625f3fd86344ff07fba2bfc3288",
#     "Created": "2015-07-22T18:04:08.241675766Z",
#     "Path": "nginx",
#     "Args": [
#         "-g",
#         "daemon off;"
#     ],
#     "State": {
#         "Running": true,
#         "Paused": false,
#         "Restarting": false,
#         "OOMKilled": false,
#         "Dead": false,
#         "Pid": 2622,
#         "ExitCode": 0,
#         "Error": "",
#         "StartedAt": "2015-07-22T18:04:08.579087107Z",
#         "FinishedAt": "0001-01-01T00:00:00Z"
#     },
#     "Image": "6886fb5a9b8d73b12d842bab8f9a6941c36094c2974abddb685d54c9d99e37da",
#     "NetworkSettings": {
#         "Bridge": "",
#         "EndpointID": "7dd70c626487754480b125a8c0c3c7eaab83e3b804a02fb9a92d704d53ddae4b",
#         "Gateway": "172.17.42.1",
#         "GlobalIPv6Address": "",
#         "GlobalIPv6PrefixLen": 0,
#         "HairpinMode": false,
#         "IPAddress": "172.17.0.7",
#         "IPPrefixLen": 16,
#         "IPv6Gateway": "",
#         "LinkLocalIPv6Address": "",
#         "LinkLocalIPv6PrefixLen": 0,
#         "MacAddress": "02:42:ac:11:00:07",
#         "NetworkID": "0ab1cedd33f7b8a43bf2ddb74e8bdf33994f2cbeb971444b806ba2d64c2d20fe",
#         "PortMapping": null,
#         "Ports": {
#             "443/tcp": null,
#             "80/tcp": null
#         },
#         "SandboxKey": "/var/run/docker/netns/5ace7dc12696",
#         "SecondaryIPAddresses": null,
#         "SecondaryIPv6Addresses": null
#     },
#     "ResolvConfPath": "/mnt/sda1/var/lib/docker/containers/5ace7dc12696625d8e2eed9635a71bd8fd325625f3fd86344ff07fba2bfc3288/resolv.conf",
#     "HostnamePath": "/mnt/sda1/var/lib/docker/containers/5ace7dc12696625d8e2eed9635a71bd8fd325625f3fd86344ff07fba2bfc3288/hostname",
#     "HostsPath": "/mnt/sda1/var/lib/docker/containers/5ace7dc12696625d8e2eed9635a71bd8fd325625f3fd86344ff07fba2bfc3288/hosts",
#     "LogPath": "/mnt/sda1/var/lib/docker/containers/5ace7dc12696625d8e2eed9635a71bd8fd325625f3fd86344ff07fba2bfc3288/5ace7dc12696625d8e2eed9635a71bd8fd325625f3fd86344ff07fba2bfc3288-json.log",
#     "Name": "/web",
#     "RestartCount": 0,
#     "Driver": "aufs",
#     "ExecDriver": "native-0.2",
#     "MountLabel": "",
#     "ProcessLabel": "",
#     "Volumes": {
#         "/var/cache/nginx": "/mnt/sda1/var/lib/docker/volumes/36d3166d6eecb5afe032d22f4cf0a379b64a8729418513f309d74cd3312fbf09/_data"
#     },
#     "VolumesRW": {
#         "/var/cache/nginx": true
#     },
#     "AppArmorProfile": "",
#     "ExecIDs": null,
#     "HostConfig": {
#         "Binds": null,
#         "ContainerIDFile": "",
#         "LxcConf": [],
#         "Memory": 0,
#         "MemorySwap": 0,
#         "CpuShares": 0,
#         "CpuPeriod": 0,
#         "CpusetCpus": "",
#         "CpusetMems": "",
#         "CpuQuota": 0,
#         "BlkioWeight": 0,
#         "OomKillDisable": false,
#         "Privileged": false,
#         "PortBindings": {},
#         "Links": null,
#         "PublishAllPorts": false,
#         "Dns": null,
#         "DnsSearch": null,
#         "ExtraHosts": null,
#         "VolumesFrom": null,
#         "Devices": [],
#         "NetworkMode": "bridge",
#         "IpcMode": "",
#         "PidMode": "",
#         "UTSMode": "",
#         "CapAdd": null,
#         "CapDrop": null,
#         "RestartPolicy": {
#             "Name": "no",
#             "MaximumRetryCount": 0
#         },
#         "SecurityOpt": null,
#         "ReadonlyRootfs": false,
#         "Ulimits": null,
#         "LogConfig": {
#             "Type": "json-file",
#             "Config": {}
#         },
#         "CgroupParent": ""
#     },
#     "Config": {
#         "Hostname": "5ace7dc12696",
#         "Domainname": "",
#         "User": "",
#         "AttachStdin": false,
#         "AttachStdout": false,
#         "AttachStderr": false,
#         "PortSpecs": null,
#         "ExposedPorts": {
#             "443/tcp": {},
#             "80/tcp": {}
#         },
#         "Tty": false,
#         "OpenStdin": false,
#         "StdinOnce": false,
#         "Env": [
#             "PATH=/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin",
#             "NGINX_VERSION=1.9.3-1~jessie"
#         ],
#         "Cmd": [
#             "nginx",
#             "-g",
#             "daemon off;"
#         ],
#         "Image": "nginx",
#         "Volumes": {
#             "/var/cache/nginx": {}
#         },
#         "VolumeDriver": "",
#         "WorkingDir": "",
#         "Entrypoint": null,
#         "NetworkDisabled": false,
#         "MacAddress": "",
#         "OnBuild": null,
#         "Labels": {}
#     }
# }
# ]

# %%
docker inspect hello-world
# Out:
# [
# {
#     "Id": "91c95931e552b11604fea91c2f537284149ec32fff0f700a4769cfd31d7696ae",
#     "Parent": "a8219747be10611d65b7c693f48e7222c0bf54b5df8467d3f99003611afa1fd8",
#     "Comment": "",
#     "Created": "2015-04-17T22:01:38.74474669Z",
#     "Container": "724582a033a54c0864aab1e37d7bfaea9a3228bc63282df0dd07dd5768da40be",
#     "ContainerConfig": {
#         "Hostname": "d7c065bb52d8",
#         "Domainname": "",
#         "User": "",
#         "AttachStdin": false,
#         "AttachStdout": false,
#         "AttachStderr": false,
#         "PortSpecs": null,
#         "ExposedPorts": null,
#         "Tty": false,
#         "OpenStdin": false,
#         "StdinOnce": false,
#         "Env": null,
#         "Cmd": [
#             "/bin/sh",
#             "-c",
#             "#(nop) CMD [\"/hello\"]"
#         ],
#         "Image": "a8219747be10611d65b7c693f48e7222c0bf54b5df8467d3f99003611afa1fd8",
#         "Volumes": null,
#         "VolumeDriver": "",
#         "WorkingDir": "",
#         "Entrypoint": null,
#         "NetworkDisabled": false,
#         "MacAddress": "",
#         "OnBuild": null,
#         "Labels": {}
#     },
#     "DockerVersion": "1.6.0",
#     "Author": "",
#     "Config": {
#         "Hostname": "d7c065bb52d8",
#         "Domainname": "",
#         "User": "",
#         "AttachStdin": false,
#         "AttachStdout": false,
#         "AttachStderr": false,
#         "PortSpecs": null,
#         "ExposedPorts": null,
#         "Tty": false,
#         "OpenStdin": false,
#         "StdinOnce": false,
#         "Env": null,
#         "Cmd": [
#             "/hello"
#         ],
#         "Image": "a8219747be10611d65b7c693f48e7222c0bf54b5df8467d3f99003611afa1fd8",
#         "Volumes": null,
#         "VolumeDriver": "",
#         "WorkingDir": "",
#         "Entrypoint": null,
#         "NetworkDisabled": false,
#         "MacAddress": "",
#         "OnBuild": null,
#         "Labels": {}
#     },
#     "Architecture": "amd64",
#     "Os": "linux",
#     "Size": 0,
#     "VirtualSize": 910
# }
# ]

# %% [markdown]
# Notice that there are no `NetworkSettings` for `hello-world` because it is not running.

# %%
docker stop web
# Out:
# web

# %%
docker rm web
# Out:
# web

# %% [markdown]
# ---

# %%
cat Dockerfile
# Out:
# ######################################################################################
# #                                                                                    #
# # To build: docker build -t ubuntu:scribengin directory                              #
# # To run:   docker run -t -i ubuntu:scribengin  /bin/bash                            #
# #                                                                                    #
# ######################################################################################
#
# # We use the CentOS version 7 as a base for our own image that is described by this file.
# FROM centos:7
# MAINTAINER Galvanize
#
# RUN echo "Expose SSH port"
# EXPOSE 22
#
# RUN echo "Install openssh"
# RUN yum -y install openssl openssh-server passwd shadow-utils sudo && yum clean all
#
# RUN echo "Configure root Account"
# RUN mkdir /var/run/sshd
# RUN echo 'root:root' | chpasswd
#
#
# RUN echo "SSH login fix for Docker"
# RUN sed -i 's/PermitRootLogin without-password/PermitRootLogin yes/' /etc/ssh/sshd_config
# RUN sed 's@session\s*required\s*pam_loginuid.so@session optional pam_loginuid.so@g' -i /etc/pam.d/sshd
# ENV NOTVISIBLE "in users profile"
# RUN echo "export VISIBLE=now" >> /etc/profile
# RUN echo "PermitUserEnvironment yes" >> /etc/ssh/sshd_config
#
# RUN echo "Setup gstudent user with sudo-rights (no password needed)"
# RUN useradd -m -d /home/gstudent -s /bin/bash -c "gstudent user" -p $(openssl passwd -1 gstudent)  gstudent
#
# RUN echo gstudent ALL=\(ALL\) NOPASSWD: ALL >> /etc/sudoers
# RUN echo root ALL=\(ALL\) NOPASSWD: ALL >> /etc/sudoers
#
# # allow user to login as sudo with no pwd needed for anything
# RUN echo "Sets up public keys for ssh for gstudent user.  Assumes your public keys are stored in ./tmp"
# RUN mkdir -p /home/gstudent/.ssh
# RUN chown -R gstudent:gstudent /home/gstudent/.ssh
# RUN chmod 700 /home/gstudent/.ssh
# ADD tmp/authorized_keys /home/gstudent/.ssh/authorized_keys
# RUN chmod 644 /home/gstudent/.ssh/authorized_keys
#
#
#
# RUN ssh-keygen -A
# RUN echo "Start sshd service"
# CMD ["/usr/sbin/sshd", "-D"]

# %% [markdown]
# Copy your public key into `tmp/authorized_keys`
# *e.g.*:
# ```bash
# mkdir tmp
# cp ~/.ssh/id_rsa.pub tmp/authorized_keys
# ```

# %%
docker build -t testimg .
# Out:
# Sending build context to Docker daemon 56.83 kB
# Sending build context to Docker daemon
# Step 0 : FROM centos:7
# 7: Pulling from centos
#
# f1b10cd84249: Pulling fs layer
# c852f6d61e65: Pulling fs layer
# centos:7: The image you are pulling has been verified. Important: image verification is a tech preview feature and should not be relied on to provide security.
# Digest: sha256:c65da3ab236f6368a3e2722a6f576b80f6e1de25067612ca2b55506d9b554dba
# Status: Downloaded newer image for centos:7
#  ---> 7322fbe74aa5
# Step 1 : MAINTAINER Galvanize
#  ---> Running in c13ba6ea49a6
#  ---> 1d6d36d746ee
# Removing intermediate container c13ba6ea49a6
# Step 2 : RUN echo "Expose SSH port"
#  ---> Running in 45fc45d7d5b2
# Expose SSH port
#  ---> 6f3cf19dfd0d
# Removing intermediate container 45fc45d7d5b2
# Step 3 : EXPOSE 22
#  ---> Running in 79c1a220d516
#  ---> d7725800d30d
# Removing intermediate container 79c1a220d516
# Step 4 : RUN echo "Install openssh"
#  ---> Running in 34a41ad1ab29
# Install openssh
#  ---> 805f42d5d334
# Removing intermediate container 34a41ad1ab29
# Step 5 : RUN yum -y install openssl openssh-server passwd shadow-utils sudo && yum clean all
#  ---> Running in 744100757bdb
# Loaded plugins: fastestmirror
# Determining fastest mirrors
#  * base: mirrors.syringanetworks.net
#  * extras: centos.sonn.com
#  * updates: centos.mirrors.hoobly.com
# Package 2:shadow-utils-4.1.5.1-18.el7.x86_64 already installed and latest version
# Resolving Dependencies
# --> Running transaction check
# ---> Package openssh-server.x86_64 0:6.6.1p1-12.el7_1 will be installed
# --> Processing Dependency: openssh = 6.6.1p1-12.el7_1 for package: openssh-server-6.6.1p1-12.el7_1.x86_64
# --> Processing Dependency: fipscheck-lib(x86-64) >= 1.3.0 for package: openssh-server-6.6.1p1-12.el7_1.x86_64
# --> Processing Dependency: libwrap.so.0()(64bit) for package: openssh-server-6.6.1p1-12.el7_1.x86_64
# --> Processing Dependency: libfipscheck.so.1()(64bit) for package: openssh-server-6.6.1p1-12.el7_1.x86_64
# ---> Package openssl.x86_64 1:1.0.1e-42.el7.9 will be installed
# --> Processing Dependency: openssl-libs(x86-64) = 1:1.0.1e-42.el7.9 for package: 1:openssl-1.0.1e-42.el7.9.x86_64
# --> Processing Dependency: make for package: 1:openssl-1.0.1e-42.el7.9.x86_64
# ---> Package passwd.x86_64 0:0.79-4.el7 will be installed
# ---> Package sudo.x86_64 0:1.8.6p7-13.el7 will be installed
# --> Running transaction check
# ---> Package fipscheck-lib.x86_64 0:1.4.1-5.el7 will be installed
# --> Processing Dependency: /usr/bin/fipscheck for package: fipscheck-lib-1.4.1-5.el7.x86_64
# ---> Package make.x86_64 1:3.82-21.el7 will be installed
# ---> Package openssh.x86_64 0:6.6.1p1-12.el7_1 will be installed
# ---> Package openssl-libs.x86_64 1:1.0.1e-42.el7.8 will be updated
# ---> Package openssl-libs.x86_64 1:1.0.1e-42.el7.9 will be an update
# ---> Package tcp_wrappers-libs.x86_64 0:7.6-77.el7 will be installed
# --> Running transaction check
# ---> Package fipscheck.x86_64 0:1.4.1-5.el7 will be installed
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package                Arch        Version                  Repository    Size
# ================================================================================
# Installing:
#  openssh-server         x86_64      6.6.1p1-12.el7_1         updates      432 k
#  openssl                x86_64      1:1.0.1e-42.el7.9        updates      711 k
#  passwd                 x86_64      0.79-4.el7               base         105 k
#  sudo                   x86_64      1.8.6p7-13.el7           base         718 k
# Installing for dependencies:
#  fipscheck              x86_64      1.4.1-5.el7              base          21 k
#  fipscheck-lib          x86_64      1.4.1-5.el7              base          11 k
#  make                   x86_64      1:3.82-21.el7            base         420 k
#  openssh                x86_64      6.6.1p1-12.el7_1         updates      431 k
#  tcp_wrappers-libs      x86_64      7.6-77.el7               base          66 k
# Updating for dependencies:
#  openssl-libs           x86_64      1:1.0.1e-42.el7.9        updates      949 k
#
# Transaction Summary
# ================================================================================
# Install  4 Packages (+5 Dependent packages)
# Upgrade             ( 1 Dependent package)
#
# Total download size: 3.8 M
# Downloading packages:
# Delta RPMs disabled because /usr/bin/applydeltarpm not installed.
# warning: /var/cache/yum/x86_64/7/base/packages/fipscheck-lib-1.4.1-5.el7.x86_64.rpm: Header V3 RSA/SHA256 Signature, key ID f4a80eb5: NOKEY
# Public key for fipscheck-lib-1.4.1-5.el7.x86_64.rpm is not installed
# Public key for openssh-6.6.1p1-12.el7_1.x86_64.rpm is not installed
# --------------------------------------------------------------------------------
# Total                                              3.1 MB/s | 3.8 MB  00:01
# Retrieving key from file:///etc/pki/rpm-gpg/RPM-GPG-KEY-CentOS-7
# Importing GPG key 0xF4A80EB5:
#  Userid     : "CentOS-7 Key (CentOS 7 Official Signing Key) <security@centos.org>"
#  Fingerprint: 6341 ab27 53d7 8a78 a7c2 7bb1 24c6 a8a7 f4a8 0eb5
#  Package    : centos-release-7-1.1503.el7.centos.2.8.x86_64 (@CentOS)
#  From       : /etc/pki/rpm-gpg/RPM-GPG-KEY-CentOS-7
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
#   Updating   : 1:openssl-libs-1.0.1e-42.el7.9.x86_64                       1/11
#   Installing : fipscheck-lib-1.4.1-5.el7.x86_64                            2/11
#   Installing : fipscheck-1.4.1-5.el7.x86_64                                3/11
#   Installing : openssh-6.6.1p1-12.el7_1.x86_64                             4/11
#   Installing : tcp_wrappers-libs-7.6-77.el7.x86_64                         5/11
#   Installing : 1:make-3.82-21.el7.x86_64                                   6/11
#   Installing : 1:openssl-1.0.1e-42.el7.9.x86_64                            7/11
#   Installing : openssh-server-6.6.1p1-12.el7_1.x86_64                      8/11
#   Installing : sudo-1.8.6p7-13.el7.x86_64                                  9/11
#   Installing : passwd-0.79-4.el7.x86_64                                   10/11
#   Cleanup    : 1:openssl-libs-1.0.1e-42.el7.8.x86_64                      11/11
#   Verifying  : 1:openssl-libs-1.0.1e-42.el7.9.x86_64                       1/11
#   Verifying  : openssh-server-6.6.1p1-12.el7_1.x86_64                      2/11
#   Verifying  : 1:make-3.82-21.el7.x86_64                                   3/11
#   Verifying  : tcp_wrappers-libs-7.6-77.el7.x86_64                         4/11
#   Verifying  : passwd-0.79-4.el7.x86_64                                    5/11
#   Verifying  : sudo-1.8.6p7-13.el7.x86_64                                  6/11
#   Verifying  : fipscheck-lib-1.4.1-5.el7.x86_64                            7/11
#   Verifying  : fipscheck-1.4.1-5.el7.x86_64                                8/11
#   Verifying  : openssh-6.6.1p1-12.el7_1.x86_64                             9/11
#   Verifying  : 1:openssl-1.0.1e-42.el7.9.x86_64                           10/11
#   Verifying  : 1:openssl-libs-1.0.1e-42.el7.8.x86_64                      11/11
#
# Installed:
#   openssh-server.x86_64 0:6.6.1p1-12.el7_1   openssl.x86_64 1:1.0.1e-42.el7.9
#   passwd.x86_64 0:0.79-4.el7                 sudo.x86_64 0:1.8.6p7-13.el7
#
# Dependency Installed:
#   fipscheck.x86_64 0:1.4.1-5.el7           fipscheck-lib.x86_64 0:1.4.1-5.el7
#   make.x86_64 1:3.82-21.el7                openssh.x86_64 0:6.6.1p1-12.el7_1
#   tcp_wrappers-libs.x86_64 0:7.6-77.el7
#
# Dependency Updated:
#   openssl-libs.x86_64 1:1.0.1e-42.el7.9
#
# Complete!
# Loaded plugins: fastestmirror
# Cleaning repos: base extras updates
# Cleaning up everything
# Cleaning up list of fastest mirrors
#  ---> 4d2b0c5addea
# Removing intermediate container 744100757bdb
# Step 6 : RUN echo "Configure root Account"
#  ---> Running in 449ef89048cb
# Configure root Account
#  ---> be9e176d1b35
# Removing intermediate container 449ef89048cb
# Step 7 : RUN mkdir /var/run/sshd
#  ---> Running in 2a424863f8cb
#  ---> beab1013c462
# Removing intermediate container 2a424863f8cb
# Step 8 : RUN echo 'root:root' | chpasswd
#  ---> Running in 108ccb83a4e6
#  ---> 1250e9f3d28a
# Removing intermediate container 108ccb83a4e6
# Step 9 : RUN echo "SSH login fix for Docker"
#  ---> Running in 999646a9ca56
# SSH login fix for Docker
#  ---> 0ca14c78bdfa
# Removing intermediate container 999646a9ca56
# Step 10 : RUN sed -i 's/PermitRootLogin without-password/PermitRootLogin yes/' /etc/ssh/sshd_config
#  ---> Running in bd76489d3245
#  ---> 62231817cebf
# Removing intermediate container bd76489d3245
# Step 11 : RUN sed 's@session\s*required\s*pam_loginuid.so@session optional pam_loginuid.so@g' -i /etc/pam.d/sshd
#  ---> Running in e05bb6e9ae77
#  ---> ddb0afe9bf51
# Removing intermediate container e05bb6e9ae77
# Step 12 : ENV NOTVISIBLE "in users profile"
#  ---> Running in 39a68403bff0
#  ---> 716b41efd587
# Removing intermediate container 39a68403bff0
# Step 13 : RUN echo "export VISIBLE=now" >> /etc/profile
#  ---> Running in 481ea35b9ff0
#  ---> a63ef7e41c93
# Removing intermediate container 481ea35b9ff0
# Step 14 : RUN echo "PermitUserEnvironment yes" >> /etc/ssh/sshd_config
#  ---> Running in d91512d8be26
#  ---> 3fcf19d77c59
# Removing intermediate container d91512d8be26
# Step 15 : RUN echo "Setup gstudent user with sudo-rights (no password needed)"
#  ---> Running in a96164ef3004
# Setup gstudent user with sudo-rights (no password needed)
#  ---> ef01049dac45
# Removing intermediate container a96164ef3004
# Step 16 : RUN useradd -m -d /home/gstudent -s /bin/bash -c "gstudent user" -p $(openssl passwd -1 gstudent)  gstudent
#  ---> Running in 28176f9c8b30
#  ---> 71a32d09dbd2
# Removing intermediate container 28176f9c8b30
# Step 17 : RUN echo gstudent ALL=\(ALL\) NOPASSWD: ALL >> /etc/sudoers
#  ---> Running in 84996e12a875
#  ---> fb53b24e52c0
# Removing intermediate container 84996e12a875
# Step 18 : RUN echo root ALL=\(ALL\) NOPASSWD: ALL >> /etc/sudoers
#  ---> Running in 5a87fd159afe
#  ---> 865e50d67712
# Removing intermediate container 5a87fd159afe
# Step 19 : RUN echo "Sets up public keys for ssh for gstudent user.  Assumes your public keys are stored in ./tmp"
#  ---> Running in 91c6b797bb37
# Sets up public keys for ssh for gstudent user.  Assumes your public keys are stored in ./tmp
#  ---> 8a82f5322031
# Removing intermediate container 91c6b797bb37
# Step 20 : RUN mkdir -p /home/gstudent/.ssh
#  ---> Running in 4e28a3a25a8c
#  ---> 8e875b275f3f
# Removing intermediate container 4e28a3a25a8c
# Step 21 : RUN chown -R gstudent:gstudent /home/gstudent/.ssh
#  ---> Running in be5232034529
#  ---> cf6a4ee606b6
# Removing intermediate container be5232034529
# Step 22 : RUN chmod 700 /home/gstudent/.ssh
#  ---> Running in c3e990dca85c
#  ---> 536fe9729ce3
# Removing intermediate container c3e990dca85c
# Step 23 : ADD tmp/authorized_keys /home/gstudent/.ssh/authorized_keys
#  ---> 3c046805a923
# Removing intermediate container 69bd4dc966a9
# Step 24 : RUN chmod 644 /home/gstudent/.ssh/authorized_keys
#  ---> Running in 4e10439cc1e5
#  ---> 8c746d4a1615
# Removing intermediate container 4e10439cc1e5
# Step 25 : RUN ssh-keygen -A
#  ---> Running in b8882bccce3f
# ssh-keygen: generating new host keys: RSA1 RSA DSA ECDSA ED25519
#  ---> 10e67e11c802
# Removing intermediate container b8882bccce3f
# Step 26 : RUN echo "Start sshd service"
#  ---> Running in 48651af33d43
# Start sshd service
#  ---> da94e53c94c6
# Removing intermediate container 48651af33d43
# Step 27 : CMD /usr/sbin/sshd -D
#  ---> Running in f465496808c5
#  ---> 56786ac35538
# Removing intermediate container f465496808c5
# Successfully built 56786ac35538

# %%
docker images
# Out:
# REPOSITORY          TAG                 IMAGE ID            CREATED             VIRTUAL SIZE
# testimg             latest              56786ac35538        16 minutes ago      195.1 MB
# nginx               latest              6886fb5a9b8d        4 days ago          132.9 MB
# centos              7                   7322fbe74aa5        4 weeks ago         172.2 MB
# hello-world         latest              91c95931e552        3 months ago        910 B

# %%
docker run -d -p 22 --privileged -h test --name test testimg
# Out:
# dff3a4f87392642bf84822c5049ce6c4431d8c6844f0d05c669eb4bc6e1e1a1d

# %%
docker inspect test
# Out:
# [
# {
#     "Id": "dff3a4f87392642bf84822c5049ce6c4431d8c6844f0d05c669eb4bc6e1e1a1d",
#     "Created": "2015-07-22T18:54:31.784128709Z",
#     "Path": "/usr/sbin/sshd",
#     "Args": [
#         "-D"
#     ],
#     "State": {
#         "Running": true,
#         "Paused": false,
#         "Restarting": false,
#         "OOMKilled": false,
#         "Dead": false,
#         "Pid": 3458,
#         "ExitCode": 0,
#         "Error": "",
#         "StartedAt": "2015-07-22T18:54:32.113814411Z",
#         "FinishedAt": "0001-01-01T00:00:00Z"
#     },
#     "Image": "56786ac3553853c22d5124bafafade006f2d03d37f7bf55cb0a39b5b54bfd51d",
#     "NetworkSettings": {
#         "Bridge": "",
#         "EndpointID": "d4b5cf7953149bc44c759f554a934412ebb437bcc9da3209df6e9fbb06f75a61",
#         "Gateway": "172.17.42.1",
#         "GlobalIPv6Address": "",
#         "GlobalIPv6PrefixLen": 0,
#         "HairpinMode": false,
#         "IPAddress": "172.17.0.30",
#         "IPPrefixLen": 16,
#         "IPv6Gateway": "",
#         "LinkLocalIPv6Address": "",
#         "LinkLocalIPv6PrefixLen": 0,
#         "MacAddress": "02:42:ac:11:00:1e",
#         "NetworkID": "0ab1cedd33f7b8a43bf2ddb74e8bdf33994f2cbeb971444b806ba2d64c2d20fe",
#         "PortMapping": null,
#         "Ports": {
#             "22/tcp": [
#                 {
#                     "HostIp": "0.0.0.0",
#                     "HostPort": "32772"
#                 }
#             ]
#         },
#         "SandboxKey": "/var/run/docker/netns/dff3a4f87392",
#         "SecondaryIPAddresses": null,
#         "SecondaryIPv6Addresses": null
#     },
#     "ResolvConfPath": "/mnt/sda1/var/lib/docker/containers/dff3a4f87392642bf84822c5049ce6c4431d8c6844f0d05c669eb4bc6e1e1a1d/resolv.conf",
#     "HostnamePath": "/mnt/sda1/var/lib/docker/containers/dff3a4f87392642bf84822c5049ce6c4431d8c6844f0d05c669eb4bc6e1e1a1d/hostname",
#     "HostsPath": "/mnt/sda1/var/lib/docker/containers/dff3a4f87392642bf84822c5049ce6c4431d8c6844f0d05c669eb4bc6e1e1a1d/hosts",
#     "LogPath": "/mnt/sda1/var/lib/docker/containers/dff3a4f87392642bf84822c5049ce6c4431d8c6844f0d05c669eb4bc6e1e1a1d/dff3a4f87392642bf84822c5049ce6c4431d8c6844f0d05c669eb4bc6e1e1a1d-json.log",
#     "Name": "/test",
#     "RestartCount": 0,
#     "Driver": "aufs",
#     "ExecDriver": "native-0.2",
#     "MountLabel": "",
#     "ProcessLabel": "",
#     "Volumes": {},
#     "VolumesRW": {},
#     "AppArmorProfile": "",
#     "ExecIDs": null,
#     "HostConfig": {
#         "Binds": null,
#         "ContainerIDFile": "",
#         "LxcConf": [],
#         "Memory": 0,
#         "MemorySwap": 0,
#         "CpuShares": 0,
#         "CpuPeriod": 0,
#         "CpusetCpus": "",
#         "CpusetMems": "",
#         "CpuQuota": 0,
#         "BlkioWeight": 0,
#         "OomKillDisable": false,
#         "Privileged": true,
#         "PortBindings": {
#             "22/tcp": [
#                 {
#                     "HostIp": "",
#                     "HostPort": ""
#                 }
#             ]
#         },
#         "Links": null,
#         "PublishAllPorts": false,
#         "Dns": null,
#         "DnsSearch": null,
#         "ExtraHosts": null,
#         "VolumesFrom": null,
#         "Devices": [],
#         "NetworkMode": "bridge",
#         "IpcMode": "",
#         "PidMode": "",
#         "UTSMode": "",
#         "CapAdd": null,
#         "CapDrop": null,
#         "RestartPolicy": {
#             "Name": "no",
#             "MaximumRetryCount": 0
#         },
#         "SecurityOpt": null,
#         "ReadonlyRootfs": false,
#         "Ulimits": null,
#         "LogConfig": {
#             "Type": "json-file",
#             "Config": {}
#         },
#         "CgroupParent": ""
#     },
#     "Config": {
#         "Hostname": "test",
#         "Domainname": "",
#         "User": "",
#         "AttachStdin": false,
#         "AttachStdout": false,
#         "AttachStderr": false,
#         "PortSpecs": null,
#         "ExposedPorts": {
#             "22/tcp": {}
#         },
#         "Tty": false,
#         "OpenStdin": false,
#         "StdinOnce": false,
#         "Env": [
#             "PATH=/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin",
#             "NOTVISIBLE=in users profile"
#         ],
#         "Cmd": [
#             "/usr/sbin/sshd",
#             "-D"
#         ],
#         "Image": "testimg",
#         "Volumes": null,
#         "VolumeDriver": "",
#         "WorkingDir": "",
#         "Entrypoint": null,
#         "NetworkDisabled": false,
#         "MacAddress": "",
#         "OnBuild": null,
#         "Labels": {}
#     }
# }
# ]

# %% [markdown]
# Get IPAddress from `docker inspect` and put it in
# ```bash
# sudo route -n add {$IPAddress}/16 `boot2docker ip`
# ```
#
# for example, if your `"IPAddress": "172.17.0.30"`:
# ```bash
# sudo route -n add 172.17.0.30/16 `boot2docker ip`
# ```
#
# test:
# ```bash
# ping -o 172.17.0.30
# ```
# finally:
# ```bash
# ssh gstudent@172.17.0.30
# ```

# %% [markdown]
# Lab
# ===
# 1. Add the default postgres port to the Dockerfile
# 2. ...
#
# Install Ansible on your local machine
# - Ansible can run from anywhere; and all it does is connect to machines using SSH to run its Tasks
#
# Installing Ansible on Linux/Mac:

# %%
# todo: use pip install for Ansible for cross-platform consistency
sudo apt-add-repository -y ppa:ansible/ansible
sudo apt-get update
sudo apt-get install -y ansible

# %% [markdown]
# Let's try the simplest possible Ansible command:

# %%
ansible all -i 'localhost,' -c local -m ping

# %%
localhost | success >> {
    "changed": false, 
    "ping": "pong"
}

# %% [markdown]
# Here's what this line did:
# - 'all': tells ansible to run the task against all hosts in its inventory
# - '-i localhost,': the -i flag provides ansible with either the path to an inventory file, OR a list of host names (NOTE: the comma tells Ansible we're providing a list instead of a filepath)
# - '-c local': use local connection instead of SSH'ing into any remote hosts.
# - '-m ping': use the 'ping' module.
